# %% [markdown]
# ##### Canned question: Mechanism of Action (MoA) cross-results
#
# This is a simple demo showing how we can use an LLM to group results from Translator according to their mechanisms of action.

# %%
from graphwerk import trapimsg
import summarizers.trapi_tools as tools
import summarizers.common_utils as cu
from driver import load_trapi_response

# %%
trapi_path = 'data/101635ed-6bb7-46fc-a2f1-96d814c34040.json'
trapi_response_msg = load_trapi_response(trapi_path)

# %%
orig_msg = trapi_response_msg['fields']['data']['message']
orig_kg = orig_msg['knowledge_graph']
orig_ag = orig_msg['auxiliary_graphs']
orig_qg = orig_msg['query_graph']
retval = ''
object_node_id, object_node_data = tools.get_object_node_data(orig_qg, orig_kg)
res_nodes = {} # The node section is universal, not per-result

per_result = ''
counter = 1
# fetch the first 10 results for manually reviewing
idx_range = range(0, min(10, len(orig_msg['results'])))
pub_cutoff = 0
for i in idx_range:
    cur_res = orig_msg['results'][i]
    subject_id = cur_res['node_bindings']['sn'][0]['id']
    subject_name = orig_kg['nodes'][subject_id]['name']
    per_result += f"** Result {counter}: {subject_name}\n"
    res_edges = {}
    res_sgs = {}
    trapimsg.collect_edges_and_sgs_for_res_elem(cur_res, orig_kg, orig_ag, res_edges, res_sgs)
    trapimsg.collect_nodes_for_edge_collection(res_edges, orig_kg, res_nodes)
    presum_edges = tools.create_edge_presummary_raw_data(res_edges, res_nodes, pub_cutoff)
    presum_nodes = tools.create_node_presummary_raw_data(res_nodes)
    per_result += cu.create_edge_data_summary(presum_edges, 1) + '\n'
    counter += 1

# %%
# print(per_result.rstrip())

# %%
def generate_prompt(results):
    if results:
        prompt = f"""I’m not looking for detailed mechanism of actions of each drug/chemical. Please analyze the cross-result patterns across all inferred paths in the provided results: what common MoA themes, gene targets, or pathways emerge? Group the drugs/chemicals into categories based on shared mechanisms rather than listing them individually.
Results: 
{results}
        """
    else: prompt = None

    return prompt

# %%
prompt = generate_prompt(per_result.rstrip())
print(prompt)
# Out:
# I’m not looking for detailed mechanism of actions of each drug/chemical. Please analyze the cross-result patterns across all inferred paths in the provided results: what common MoA themes, gene targets, or pathways emerge? Group the drugs/chemicals into categories based on shared mechanisms rather than listing them individually.
# Results:
# ** Result 1: Prednisone
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | Prednisone | treats_or_applied_or_studied_to_treat | Multiple Pulmonary Nodules |  |  |
#
# ** Result 2: dexamethasone sodium phosphate
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | dexamethasone sodium phosphate | in_clinical_trials_for | Nodule of lung |  | NCT00906503 |
# | NCF2 | gene_associated_with_condition | Nodule of lung |  |  |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | HLA-DPA1 | gene_associated_with_condition | Nodule of lung |  |  |
# | dexamethasone sodium phosphate | affects | NCF2 |  |  |
# | dexamethasone sodium phosphate | affects | STAT1 |  |  |
# | dexamethasone sodium phosphate | affects | CTLA4 |  |  |
# | dexamethasone sodium phosphate | affects | HLA-DPA1 |  |  |
# | Nodule of lung | occurs_together_in_literature_with | dexamethasone sodium phosphate |  |  |
#
# ** Result 3: hydromorphone hydrochloride
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | hydromorphone hydrochloride | in_clinical_trials_for | Nodule of lung |  | NCT05848635 |
# | Nodule of lung | occurs_together_in_literature_with | hydromorphone hydrochloride |  |  |
#
# ** Result 4: Interferon Gamma
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | NCF2 | gene_associated_with_condition | Nodule of lung |  |  |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | PTPN22 | gene_associated_with_condition | Nodule of lung |  |  |
# | HLA-DPB1 | gene_associated_with_condition | Nodule of lung |  |  |
# | HLA-DPA1 | gene_associated_with_condition | Nodule of lung |  |  |
# | Interferon Gamma | affects | NCF2 |  |  |
# | Interferon Gamma | affects | STAT1 |  |  |
# | Interferon Gamma | affects | CTLA4 |  |  |
# | Interferon Gamma | affects | PTPN22 |  |  |
# | Interferon Gamma | affects | HLA-DPB1 |  |  |
# | Interferon Gamma | affects | HLA-DPA1 |  |  |
#
# ** Result 5: D-glucopyranose
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | NCF2 | gene_associated_with_condition | Nodule of lung |  |  |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | HLA-DPA1 | gene_associated_with_condition | Nodule of lung |  |  |
# | D-glucopyranose | affects | NCF2 |  |  |
# | D-glucopyranose | affects | STAT1 |  |  |
# | D-glucopyranose | affects | CTLA4 |  |  |
# | D-glucopyranose | affects | HLA-DPA1 |  |  |
#
# ** Result 6: Tocilizumab
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | PTPN22 | gene_associated_with_condition | Nodule of lung |  |  |
# | PRTN3 | gene_associated_with_condition | Nodule of lung |  |  |
# | Tocilizumab | affects | STAT1 |  |  |
# | Tocilizumab | affects | CTLA4 |  |  |
# | Tocilizumab | affects | PTPN22 |  |  |
# | Tocilizumab | affects | PRTN3 |  |  |
#
# ** Result 7: Interleukin-10
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | PTPN22 | gene_associated_with_condition | Nodule of lung |  |  |
# | PRTN3 | gene_associated_with_condition | Nodule of lung |  |  |
# | Interleukin-10 | affects | STAT1 |  |  |
# | Interleukin-10 | affects | CTLA4 |  |  |
# | Interleukin-10 | affects | PTPN22 |  |  |
# | Interleukin-10 | affects | PRTN3 |  |  |
#
# ** Result 8: Binetrakin
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | NCF2 | gene_associated_with_condition | Nodule of lung |  |  |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | PTPN22 | gene_associated_with_condition | Nodule of lung |  |  |
# | Binetrakin | affects | NCF2 |  |  |
# | Binetrakin | affects | STAT1 |  |  |
# | Binetrakin | affects | CTLA4 |  |  |
# | Binetrakin | affects | PTPN22 |  |  |
#
# ** Result 9: Tretinoin
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | NCF2 | gene_associated_with_condition | Nodule of lung |  |  |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | PRTN3 | gene_associated_with_condition | Nodule of lung |  |  |
# | Tretinoin | affects | NCF2 |  |  |
# | Tretinoin | affects | STAT1 |  |  |
# | Tretinoin | affects | CTLA4 |  |  |
# | Tretinoin | affects | PRTN3 |  |  |
#
# ** Result 10: Fluorouracil
# | <SUBJECT> | <PREDICATE> | <OBJECT> | <PUBMED IDS> | <CLINICAL TRIAL IDS> |
# | STAT1 | gene_associated_with_condition | Nodule of lung |  |  |
# | CTLA4 | gene_associated_with_condition | Nodule of lung |  |  |
# | HLA-DPB1 | gene_associated_with_condition | Nodule of lung |  |  |
# | HLA-DPA1 | gene_associated_with_condition | Nodule of lung |  |  |
# | Fluorouracil | affects | STAT1 |  |  |
# | Fluorouracil | affects | CTLA4 |  |  |
# | Fluorouracil | affects | HLA-DPB1 |  |  |
# | Fluorouracil | affects | HLA-DPA1 |  |  |

# %%
from ollama import Client

client = Client()

if prompt:
    messages = [
      {
        'role': 'user',
        'content': prompt,
      },
    ]
    
    response = client.chat(
        model='gpt-oss:20b',
        messages=messages,
        options={'num_ctx': 8192},  # 8192 is the recommended lower limit for the context window
      )

    response_content = response['message']['content']
else:
    response_content = "No prompt is provided."

print(response_content)
# Out:
# **Cross‑pathway overview**
#
# | Category | Core mechanism(s) | Shared gene‑targets / pathways | Representative drugs (listed as *type* rather than each name) |
# |----------|-------------------|---------------------------------|--------------------------------------------------------------|
# | **1. Glucocorticoid‑mediated transcriptional re‑pression** | Activation of the glucocorticoid receptor (GR) → recruitment of histone deacetylases & co‑repressors → suppression of NF‑κB, AP‑1, and STAT1‑driven transcription. | **STAT1, CTLA4, NCF2** (down‑regulated); also dampens HLA‑DP expression indirectly. | Prednisone, Dexamethasone (and analogues) |
# | **2. Cytokine/Immune‑checkpoint modulators that act through JAK‑STAT / CTLA4** | Exogenous cytokines or receptor antagonists alter the JAK‑STAT cascade (primarily STAT1) and/or directly influence T‑cell costimulatory molecules. | **STAT1, CTLA4, PTPN22, PRTN3** (modulated); also influence HLA‑DP genes. | Interferon‑γ, IL‑10, Tocilizumab (IL‑6R blockade), Binetrakin (neutrophil‑related), Tretinoin (retinoid‑induced gene changes) |
# | **3. Cytotoxic / anti‑proliferative agents** | Inhibit DNA synthesis or damage DNA (5‑FU) or induce differentiation (Tretinoin). | **STAT1, CTLA4, HLA‑DP** are secondary read‑outs of cell‑cycle arrest or differentiation. | Fluorouracil, Tretinoin |
# | **4. Metabolic / carbohydrate‑based immune modulation** | Simple sugars (glucose‑pyranoside) can act as ligands for lectin‑type receptors or alter cellular NADPH/NADP⁺ ratios, indirectly modulating NCF2 (oxidative burst) and STAT1 signaling. | **NCF2, STAT1, CTLA4, HLA‑DP** | D‑glucopyranose (sugar analogue) |
# | **5. Opioid‑analgesic with immunomodulatory side‑effects** | μ‑opioid receptor activation leads to altered cytokine milieu and reduced neutrophil activity (affecting NCF2). | **NCF2, STAT1** (down‑regulated); modest influence on CTLA4/HLA‑DP. | Hydromorphone hydrochloride (opioid) |
#
# ---
#
# ### What the patterns tell us
#
# 1. **Central immune‑regulatory axis** – Across all classes, the **STAT1/CTLA4 module** is the most common pivot. Whether the drug suppresses, activates, or merely dampens this axis, it is the key read‑out for nodule‑related pathology in the lung.
#
# 2. **Innate vs. adaptive overlap** – Genes such as **NCF2** (neutrophil oxidative burst) and **PRTN3** (neutrophil serine protease) link innate defenses, whereas **CTLA4, HLA‑DP, PTPN22** anchor adaptive T‑cell regulation. The shared influence suggests that the lung nodules involve a coordinated innate‑adaptive interplay.
#
# 3. **Pathway convergence** –
#    * **NF‑κB** is repressed by glucocorticoids, partially repressed by IFN‑γ/IL‑10, and indirectly modulated by 5‑FU/Tretinoin.
#    * **JAK‑STAT** (particularly STAT1) is the downstream conduit for most cytokine/antibody actions.
#    * **T‑cell costimulation/ checkpoints** (CTLA4) are a common downstream node, reinforcing the importance of T‑cell regulation in nodule biology.
#
# 4. **Therapeutic implications** –
#    * Drugs that **boost STAT1** (IFN‑γ) may enhance antigen presentation but could exacerbate inflammatory lesions.
#    * Agents that **block STAT1** (glucocorticoids, 5‑FU) or **suppress CTLA4** (Tocilizumab) can dampen local immune activation, potentially controlling nodule growth.
#    * Modulation of **innate‑cell genes (NCF2, PRTN3)** may influence the oxidative environment and neutrophil‑driven matrix remodeling.
#
# ---
#
# ### Take‑away
#
# - **Most drugs converge on the STAT1–CTLA4 axis**, whether by suppressing or stimulating it.
# - **Innate‑adaptive immune checkpoints** (NCF2, PRTN3, HLA‑DP, PTPN22) are secondary but essential contributors.
# - **Drug classes can be succinctly grouped** by their primary mechanistic theme (glucocorticoid repression, cytokine/immune‑checkpoint modulation, cytotoxic anti‑proliferation, metabolic sugar effects, opioid analgesic side‑effects).
#
# This categorization helps in prioritising compounds for further mechanistic studies or combination therapies aimed at modulating lung nodule biology.

# %%
# TODO:
# review the response from LLM
# propose any improvement we can do

# %%
# Next steps:
# The input results should be limited up to 10-20(?) because of the context length / attention length limitation(?)
# Need to include the node details if we do not want the knowledge from the traning data of a LLM
# Possible for the user to choose the input results?
# Tools development for LLM to fetch/retrieve better backgroud knowledge about the nodes and relations 
# from the Translator result graph. e.g. fetch gene information, gene enrichment/related genes(?), etc.
